# %% [markdown]
# # Clustering

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
all_orders = pd.read_csv('orders_allinfo_second.csv')
all_orders.head()
# Out:
#    Unnamed: 0  user_id  order_id  product_id  add_to_cart_order  reordered  \
# 0           0   202279         2       33120                  1          1
# 1           1   202279         2       28985                  2          1
# 2           2   202279         2        9327                  3          0
# 3           3   202279         2       45918                  4          1
# 4           4   202279         2       30035                  5          0
#
#             product_name  aisle_id               aisle  department_id  \
# 0     Organic Egg Whites        86                eggs             16
# 1  Michigan Organic Kale        83    fresh vegetables              4
# 2          Garlic Powder       104   spices seasonings             13
# 3         Coconut Butter        19       oils vinegars             13
# 4      Natural Sweetener        17  baking ingredients             13
#
#    department  order_hour_of_day  order_dow
# 0  dairy eggs                  9          5
# ...

# %%
all_orders = all_orders.drop(['Unnamed: 0'],axis=1)

# %%
all_orders.isna().sum()
# Out:
# user_id              0
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# product_name         0
# aisle_id             0
# aisle                0
# department_id        0
# department           0
# order_hour_of_day    0
# order_dow            0
# dtype: int64

# %% [markdown]
# ## Using Aisle to Cluster

# %% [markdown]
# As there are a almost 50.000 different products, I decided to cluster using the 134 aisles we have. The aisles group the projects in type and is therefore a more summarized view and will make the analysis less heavy and easier to interpet. I'll therefore use a crosstab for customers and the number of products they purchased in every aisle.

# %%
all_orders['product_name'].nunique()
# Out:
# 49677

# %%
cross_aisle = pd.crosstab(all_orders['user_id'], all_orders['aisle'])
cross_aisle.head()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            3                 0
# 3                             0            0                 0
# 4                             0            0                 0
# 5                             0            2                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# 3                          0                  0                0
# 4                          0                  0                0
# 5                          0                  0                0
#
# aisle    baking ingredients  baking supplies decor  beauty  beers coolers  \
# user_id
# 1                         0                      0       0              0
# ...

# %%
cross_aisle.shape
# Out:
# (206209, 134)

# %%
#there are no NaN values
nulls = [column for column in cross_aisle if cross_aisle[column].isna().sum()!=0]
nulls
# Out:
# []

# %% [markdown]
# ### PCA - Clustering - Using Standard Scaler

# %%
# As there are a lot of columns now I will use PCA to reduce the amount of variables in order to improve the ability to see trends and to create clusters
# it will also help with reducing dimensionality and speeding up my clustering algorithm
# I researched that data needs to be normalized before you can use it in a PCA analysis. This can be done using Standard Scaler, but since there are also a lot of 0's in the dataset, the data can also be normalized by taking a ratio of times purchased from the total amount of. purchased items
# i'll try the second way later in this kernel.

# %%
#normalize data so I can use it in PCA
transformer = StandardScaler()
aisle_scaled = transformer.fit_transform(cross_aisle)
aisle_scaled = pd.DataFrame(aisle_scaled,columns=cross_aisle.columns)
aisle_scaled
# Out:
# aisle   air fresheners candles  asian foods  baby accessories  \
# 0                    -0.132137    -0.331369         -0.074269
# 1                    -0.132137     0.899033         -0.074269
# 2                    -0.132137    -0.331369         -0.074269
# 3                    -0.132137    -0.331369         -0.074269
# 4                    -0.132137     0.488899         -0.074269
# ...                        ...          ...               ...
# 206204               -0.132137    -0.331369          1.802555
# 206205               -0.132137     1.309168         -0.074269
# 206206               -0.132137    -0.331369         -0.074269
# 206207               -0.132137     0.899033         -0.074269
# 206208               -0.132137     0.078765         -0.074269
#
# aisle   baby bath body care  baby food formula  bakery desserts  \
# 0                 -0.112044          -0.166422        -0.152402
# 1                 -0.112044          -0.166422        -0.152402
# ...

# %% [markdown]
# To get 0.95 of the variance explained by the PCA algorithm I use n_components = 0.95. This give the optimal number of Prinicipal Components to group the data in. I then plot the PC's that this value has generated to explain 0.95 of the variance. Then I have a look at the distibution of the components to see if I can make a cutoff somewhere.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.95)
principalComponents = pca.fit_transform(aisle_scaled)

PCA_components = pd.DataFrame(principalComponents)

# %%
plt.figure(figsize=(28,9))
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_ratio_, color = 'green')
plt.xticks(features,rotation=90)
plt.show()

# %% [markdown]
# Looking at the plot above we can see that the PCA generated 118 components. As this is way too much for a cluster analysis (works best with only 10 variables), I will have to reduce the number of variables. Looking at the distribution, I can see that the first 4 PCA differ the most until it evens out. For this reason I will use 4 PCA components for the cluster.

# %% [markdown]
# ### Clustering - Standard Scaler

# %% [markdown]
# To get divide the data into cluster I will use a for loop to determine the ideal amount of clusters. I also use a dictionary calles 'labels' that I use to append the labels to that get generated in each iteration. These labels divide the data in the best fitting way according to the amount of K_clusters the loop gives it. I'll then use the Elbow plot to determine what the best number of clusters is. I can then use the generated labels to visualze the clusters for the optimal number of clusters.

# %%
from sklearn.cluster import KMeans

K = range(2, 20)
inertia = []
labels = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(PCA_components[[0,1,2,3,4]])
    inertia.append(kmeans.inertia_)
    labels.append(kmeans.labels_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
cluster_aisle = pd.concat([PCA_components[[0,1,2,3,4,5]],pd.Series(labels[6]).rename('cluster')], axis = 1)

# %%
sns.pairplot(cluster_aisle, hue = 'cluster')

# %% [markdown]
# ### PCA - Clustering - Using Share of Total purchases in Aisles

# %% [markdown]
# As discussed above I will also use the share of number of products ordered by the total amount of products to normalize the data. This way I can see if there is a difference in the clusters and if so, which way is better.

# %%
#normalize using share of total
#I found this code on the internet and it basically takes the full datasets and divides the value in a column by the sum of that row.
# that way I get the share of those products by the total amount of products purchased by that particular customer.
#This could be a more useful way to normalize as the amount of times someone orders a particular type of product should way heavier for often bought products

aisle_share = cross_aisle.div(cross_aisle.sum(axis=1), axis=0)
aisle_share.head()
print(aisle_share.shape)
# Out:
# (206209, 134)

# %%
from sklearn.decomposition import PCA
pca_share = PCA(n_components = 0.95)
principalComponents_share = pca_share.fit_transform(aisle_share)

# %%
plt.figure(figsize=(23,8))
features_share = range(pca_share.n_components_)
plt.bar(features_share, pca_share.explained_variance_ratio_, color = 'orange')
plt.xticks(features_share)

PCA_components_share = pd.DataFrame(principalComponents_share)

# %% [markdown]
# Using the same technique for finding the PCA, I can see that the first 5 PCA's explain the most variance until it evens out.

# %%
PCA_components_share[[0,1,2,3,4,5,6,7]]
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.113443  0.039084 -0.042863  0.018865 -0.088341 -0.104549 -0.116443
# 1      -0.036988  0.108884 -0.066406 -0.123271  0.098849 -0.033960 -0.054736
# 2       0.064282  0.103962  0.000710 -0.012221 -0.046984  0.112238 -0.029812
# 3      -0.093210  0.054093  0.001867 -0.003974 -0.071356 -0.019278 -0.025115
# 4       0.094629 -0.037051 -0.024952 -0.021575  0.055369  0.107649 -0.008034
# ...          ...       ...       ...       ...       ...       ...       ...
# 206204 -0.026367  0.027732 -0.067101 -0.033285  0.118231 -0.058467  0.051550
# 206205 -0.089921 -0.045631 -0.048018  0.012692 -0.060298 -0.002377 -0.013544
# 206206 -0.024815 -0.013314 -0.003664 -0.031273  0.032279  0.021374  0.037840
# 206207 -0.009370 -0.003186 -0.045535 -0.012414  0.013405  0.056799  0.008895
# 206208 -0.064959  0.043771 -0.049615 -0.005576 -0.042041 -0.014394 -0.008538
#
#                7
# 0       0.083694
# ...

# %%
from sklearn.cluster import KMeans

K = range(2, 20)
inertia = []
labels = {}
predic = {}

for k in K:
    kmeans_share = KMeans(n_clusters=k).fit(PCA_components_share[[0,1,2,3,4,5,6,7]])
    inertia.append(kmeans_share.inertia_)
    labels[k] = kmeans_share.labels_
    predic[k] = kmeans_share.predict(PCA_components_share[[0,1,2,3,4,5,6,7]])

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
cluster_aisle_share = pd.concat([PCA_components_share[[0,1,2,3,4,5,6,7]],pd.Series(labels[6]).rename('cluster')], axis = 1)

# %%
cluster_aisle_share
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.113443  0.039084 -0.042863  0.018865 -0.088341 -0.104549 -0.116443
# 1      -0.036988  0.108884 -0.066406 -0.123271  0.098849 -0.033960 -0.054736
# 2       0.064282  0.103962  0.000710 -0.012221 -0.046984  0.112238 -0.029812
# 3      -0.093210  0.054093  0.001867 -0.003974 -0.071356 -0.019278 -0.025115
# 4       0.094629 -0.037051 -0.024952 -0.021575  0.055369  0.107649 -0.008034
# ...          ...       ...       ...       ...       ...       ...       ...
# 206204 -0.026367  0.027732 -0.067101 -0.033285  0.118231 -0.058467  0.051550
# 206205 -0.089921 -0.045631 -0.048018  0.012692 -0.060298 -0.002377 -0.013544
# 206206 -0.024815 -0.013314 -0.003664 -0.031273  0.032279  0.021374  0.037840
# 206207 -0.009370 -0.003186 -0.045535 -0.012414  0.013405  0.056799  0.008895
# 206208 -0.064959  0.043771 -0.049615 -0.005576 -0.042041 -0.014394 -0.008538
#
#                7  cluster
# ...

# %%
plt.figure(figsize=(10, 10))
plt.scatter(cluster_aisle_share[0], cluster_aisle_share[1], c=labels[6],alpha=0.25)
plt.show()

# %%
sns.pairplot(cluster_aisle_share, hue = 'cluster')
# Out:
# Error in callback <function flush_figures at 0x7f86a0169ee0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# Comparing the clusters with the 2 different ways of normalizing I can conclude that the second way (using shares) is working better. I can see that the. cluster are more distinct and the distribution of points looks sharper than in the first method. For this reason I will go with the clusters above.

# %% [markdown]
# ## Understanding the clusters

# %%
# concat cluster labels with aisle crosstab

aisle_cluster = cross_aisle
aisle_cluster['cluster'] = pd.Series(labels[6])
aisle_cluster.head()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# user_id
# 1                             0            0                 0
# 2                             0            3                 0
# 3                             0            0                 0
# 4                             0            0                 0
# 5                             0            2                 0
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# user_id
# 1                          0                  0                0
# 2                          0                  0                0
# 3                          0                  0                0
# 4                          0                  0                0
# 5                          0                  0                0
#
# aisle    baking ingredients  baking supplies decor  beauty  beers coolers  \
# user_id
# 1                         0                      0       0              0
# ...

# %%
cluster = pd.concat([pd.Series(cross_aisle.index),cluster_aisle_share],axis = 1)
cluster.head()
cluster.shape
# Out:
# (206209, 10)

# %%
cluster_aisle = cross_aisle.merge(cluster[['user_id','cluster']],how='left', on = 'user_id').drop('cluster_x',axis=1)
cluster_aisle = cluster_aisle.rename(columns={'cluster_y':'cluster'})
cluster_aisle
# Out:
#         user_id  air fresheners candles  asian foods  baby accessories  \
# 0             1                       0            0                 0
# 1             2                       0            3                 0
# 2             3                       0            0                 0
# 3             4                       0            0                 0
# 4             5                       0            2                 0
# ...         ...                     ...          ...               ...
# 206204   206205                       0            0                 1
# 206205   206206                       0            4                 0
# 206206   206207                       0            0                 0
# 206207   206208                       0            3                 0
# 206208   206209                       0            1                 0
#
#         baby bath body care  baby food formula  bakery desserts  \
# ...

# %%
cluster_aisle[cluster_aisle['user_id']== 181902]
# Out:
#         user_id  air fresheners candles  asian foods  baby accessories  \
# 181901   181902                       0            0                 0
#
#         baby bath body care  baby food formula  bakery desserts  \
# 181901                    0                  0                0
#
#         baking ingredients  baking supplies decor  beauty  ...  tea  \
# 181901                   0                      1       0  ...    0
#
#         tofu meat alternatives  tortillas flat bread  trail mix snack mix  \
# 181901                       0                     2                    0
#
#         trash bags liners  vitamins supplements  \
# 181901                  0                     0
#
#         water seltzer sparkling water  white wines  yogurt  cluster
# 181901                              0            0       0        0
#
# [1 rows x 136 columns]

# %%
cluster_0 = cluster_aisle[cluster_aisle['cluster']==0]
cluster_1 = cluster_aisle[cluster_aisle['cluster']==1]
cluster_2 = cluster_aisle[cluster_aisle['cluster']==2]
cluster_3 = cluster_aisle[cluster_aisle['cluster']==3]
cluster_4 = cluster_aisle[cluster_aisle['cluster']==4]
cluster_5 = cluster_aisle[cluster_aisle['cluster']==5]

# %%
print('Cluster 0 size:',cluster_0.shape)
print('Cluster 1 size:',cluster_1.shape)
print('Cluster 2 size:',cluster_2.shape)
print('Cluster 3 size:',cluster_3.shape)
print('Cluster 4 size:',cluster_4.shape)
print('Cluster 5 size:',cluster_5.shape)
# Out:
# Cluster 0 size: (43511, 136)
# Cluster 1 size: (14095, 136)
# Cluster 2 size: (66191, 136)
# Cluster 3 size: (5019, 136)
# Cluster 4 size: (69693, 136)
# Cluster 5 size: (7700, 136)

# %%
clusters = [cluster_0,cluster_1,cluster_2,cluster_3,cluster_4,cluster_5]

# %%
number = 0

for cluster in clusters:
    cluster_df = pd.DataFrame(cluster.drop(['cluster','user_id'],axis=1).sum().sort_values(ascending=False)).reset_index()
    plt.figure(figsize=(10,6))
    sns.barplot(x=cluster_df['index'][:10], y=cluster_df[0])
    plt.title(f'Most Ordered - Cluster {number}', fontsize=14)
    plt.xticks(rotation=90)
    plt.show()
    number += 1

# %%
orders_cluster = all_orders.merge(cluster_aisle[['user_id','cluster']],on='user_id')

# %%
orders_cluster.tail(60)

# %%
cluster0_all = orders_cluster[orders_cluster['cluster']==0]
cluster1_all = orders_cluster[orders_cluster['cluster']==1]
cluster2_all = orders_cluster[orders_cluster['cluster']==2]
cluster3_all = orders_cluster[orders_cluster['cluster']==3]
cluster4_all = orders_cluster[orders_cluster['cluster']==4]
cluster5_all = orders_cluster[orders_cluster['cluster']==5]

clusters_all = [cluster0_all,cluster1_all,cluster2_all,cluster3_all,cluster4_all,cluster5_all]

# %%
# cluster0_all.to_csv('cluster0.csv')
# cluster1_all.to_csv('cluster1.csv')
# cluster2_all.to_csv('cluster2.csv')
# cluster3_all.to_csv('cluster3.csv')
# cluster4_all.to_csv('cluster4.csv')
# cluster5_all.to_csv('cluster5.csv')

# %%
number =0
for cluster in clusters_all:
    popular_prod = cluster.groupby('product_name')['order_id'].aggregate('count').reset_index()
    popular_prod = popular_prod.sort_values('order_id',ascending=False)

    plt.figure(figsize=(23,8))
    sns.barplot(x=popular_prod['order_id'], y=popular_prod['product_name'][:15], color='orange')
    plt.title(f'Most Popular Products - Cluster {number}', fontsize=16)
    plt.show()
    number += 1

# %%
number =0
for cluster in clusters_all:
    plt.figure(figsize=(10,6))
    sns.countplot(x=cluster['order_dow'], data=cluster, color = 'green')
    plt.title(f'Orders by Day of Week - Cluster {number}', fontsize=14)
    plt.show()
    number += 1

# %%
number =0
for cluster in clusters_all:
    plt.figure(figsize=(10,6))
    sns.countplot(x=cluster['order_hour_of_day'], data=cluster, color = 'orange')
    plt.title(f'Orders by Day of Week - Cluster {number}', fontsize=14)
    plt.show()
    number += 1

# %% [markdown]
# ### Summary Clusters

# %% [markdown]
# In total I have been able to identify 6 different clusters based on purchase behaviour. I'll discuss the different clusters below:
#
# - Cluster 0: There are 43.511 customers in this cluster. They mainly purchase vegetables, followed by fruits. They buy very little other products and if they do its mainly dairy. Bananas, Spinach, Avocado, Strawberries are the most popular products. There is a big on orders on Saturday and a dip for orders on Mon trough Thurs. Most orders are placed between 9am and 4pm.
#
#
# - Cluster 1: There are 14.095 customers in this cluster. They have very high purchase preference for fruit, they barely buy any other products, but when they do it's mainly vegetables. Bananas and Strawberries are by far the most popular products. There is a small peak for order on Sunday, followed by orders on Saturday. The rest of the week is fairly even. Most orders are placed in the morning between 9am and 11am.
#
#
# - Cluster 2: There are 66.191 customers in this cluster. This cluster buys a very balanced set of products. The products they buy are almost equally distributed over fruit, chips, vegetables, cheese, water/sparkling water, yoghurt, milk and ice-cream. It seems that these people use InstaCart as a substitute for their physical grocery trips. Again, Bananas are the most popular products, followed by Soda, Milk, Bread & Strawberries. The orders are placed evenly during the week and also evenly between 9am and 5pm.
#
#
# - Cluster 3: There are 5019 customers in this cluster. People in this cluster almost only buy water/sprakling water/seltzers. If they buy something else it's snacks, dairy or fruit. The most popular products are spring water, sparkling water with either Grape Fruit, Lemon or Lime. The orders places in this cluster have a high peak on Sunday, with big dips on Saturday & Monday. Orders are mainly placed in the morning between 9am and 11am. Customers in this clusters are likely to buy water because they don't want to carry it, they also stock up on Sundays.
#
#
# - Cluster 4: There are 69.693 customers in this cluster. People in this cluster have a purchase preference for both fruit and vegetables followed by yoghurt & other dairy prodcuts. Once again, Bananas, Strawberries, Spinach & Avocados are the most popular products. Orders get placed mainly on Saturday & Sunday with a dip during the workweek. Popular orders are between 9am and 4pm.
#
#
# - Cluster 5: There are 7700 customers in this cluster. These customers have a preference for packaged produce followed by fruits. They buy few other products, but if they do it's dairy or snacks. Popular products are Avocado's, Raspberries, Bananas, Clementine. There is a peak in orders on Sunday and popular order times are betweem 9am and 11am in the morning followed by between 12pm and 4pm.
